-- %%
USE logistics_problem
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00

-- %%
SELECT TOP 25
    *
FROM Order_List
-- Out:
-- (25 rows affected)
-- Total execution time: 00:00:00.012
-- ...

-- %%
SELECT
    STDEVP(UNIT_QUANTITY) AS DD
FROM ORDER_LIST
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>DD</th></tr><tr><td>15964.755951803216</td></tr></table>
